# %% [markdown]
# <a href="https://www.kaggle.com/code/rrb8695/ipl-dataset-analysis?scriptVersionId=168270945" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/ipldata/matches.csv
# /kaggle/input/ipldata/deliveries.csv

# %%
df1 = pd.read_csv("/kaggle/input/ipldata/matches.csv")
df1
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df1.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
# How many matches are there in the dataset?
len(list(df1.index))
# Out:
# 756

# %%
#Which season had the highest number of matches?
season_match_count = df1.groupby('season')['result'].count().max()
season_match_count

#Highest season
# Out:
# 76

# %% [markdown]
# How many matches are there in the dataset?
#
#
# Which season had the highest number of matches?
#
#
# Which city hosted the most matches?
#
#
# How many matches were affected by the Duckworth-Lewis method?
#
#
# What was the average number of runs scored by the winning team?
#
#
# What was the average number of wickets lost by the losing team?
#
#
# Which team won the most matches?
#
#
# Which player has won the most "Man of the Match" awards?
#
#
# How many matches did each team win in a specific season?
#
#
# How many times did a team win the toss and the match?
#
#
# What is the win percentage of teams winning the toss?
#
#
# How many matches were won by the team batting first?
#
#
# How many matches were won by the team batting second?
#
#
# How many matches were won by a margin of more than 50 runs?
#
#
# How many matches were won by a margin of more than 5 wickets?
#
#
# Which venue hosted the most number of matches?
#
#
# How many times did each team win the IPL championship?
#
#
# What is the average number of runs scored in each season?
#
#
# What is the average number of wickets lost in each season?
#
#
# How many matches were played in each season?
#
#
# How many matches were decided by a Super Over?
#
#
# How many matches were affected by the weather (DL applied or abandoned)?
#
#
# How many times did a team win both the toss and the match by choosing to bat?
#
#
# How many times did a team win both the toss and the match by choosing to field?
#
#
# How many matches were won by each team at their home ground?
#
#
# How many matches were won by each team in away venues?
#
#
# How many times did a team successfully chase a target?
#
#
# How many matches were won by the team with the highest margin of victory?
#
#
# How many times did the team batting first win in a particular season?
#
#
# How many times did the team batting second win in a particular season?

# %% [markdown]
# #Which city hosted the most matches?
# print("Hello World")

# %%
#Which city hosted the most matchesd


df1['city'].value_counts().idxmax()
# Out:
# 'Mumbai'

# %%
# How many matches were affected by the Duckworth-Lewis method?
df1['dl_applied'].value_counts()[1]
# Out:
# 19

# %%
#What was the average number of runs scored by the winning team?
df1['win_by_runs'].sum()/df1['win_by_runs'].count()
# Out:
# 13.283068783068783

# %%
#Which team won the most matches?
df1['winner'].value_counts().idxmax()
# Out:
# 'Mumbai Indians'

# %%
# Which player has won the most "Man of the Match" awards?
df1['player_of_match'].value_counts()[0:1]
# Out:
# CH Gayle    21
# Name: player_of_match, dtype: int64

# %%
#How many matches did each team win in a specific season?
all_seasons = list(df1['season'].unique())
for season in all_seasons:
        matches = df1[df1['season'] ==  season ]
        print(f" Season {season} : Total matches played {len(matches)}")
        print(matches['winner'].value_counts())
        print("#"*20)
# Out:
#  Season 2017 : Total matches played 59
# Mumbai Indians                 12
# Rising Pune Supergiant         10
# Kolkata Knight Riders           9
# Sunrisers Hyderabad             8
# Kings XI Punjab                 7
# Delhi Daredevils                6
# Gujarat Lions                   4
# Royal Challengers Bangalore     3
# Name: winner, dtype: int64
# ####################
#  Season 2008 : Total matches played 58
# Rajasthan Royals               13
# Kings XI Punjab                10
# Chennai Super Kings             9
# Delhi Daredevils                7
# Mumbai Indians                  7
# Kolkata Knight Riders           6
# Royal Challengers Bangalore     4
# Deccan Chargers                 2
# Name: winner, dtype: int64
# ####################
#  Season 2009 : Total matches played 57
# Delhi Daredevils               10
# Royal Challengers Bangalore     9
# Deccan Chargers                 9
# Chennai Super Kings             8
# Kings XI Punjab                 7
# ...

# %%
# How many times did a team win the toss and the match?
len(df1[df1['toss_winner'] == df1['winner']])
# Out:
# 393

# %%
# What is the win percentage of teams winning the toss?
len(df1[df1['toss_winner'] == df1['winner']]) / len(df1) * 100
# Out:
# 51.98412698412699

# %%
# How many matches were won by the team batting first?
len(df1[df1['win_by_runs'] != 0 ])
# Out:
# 337

# %%
#How many matches were won by the team batting second?
len(df1[df1['win_by_runs'] == 0 ])
# Out:
# 419

# %%
#How many matches were won by a margin of more than 50 runs?
len(df1[df1['win_by_runs'] >  50 ])
# Out:
# 53

# %%
#How many matches were won by a margin of more than 5 wickets?

len(df1[df1['win_by_wickets'] >  5 ])
# Out:
# 267

# %%
df1['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
#Which venue hosted the most number of matches
df1[['venue','city']].value_counts()
# Out:
# venue                                                 city
# Eden Gardens                                          Kolkata           77
# Wankhede Stadium                                      Mumbai            73
# Feroz Shah Kotla                                      Delhi             67
# M Chinnaswamy Stadium                                 Bangalore         66
# Rajiv Gandhi International Stadium, Uppal             Hyderabad         56
# MA Chidambaram Stadium, Chepauk                       Chennai           49
# Sawai Mansingh Stadium                                Jaipur            47
# Punjab Cricket Association Stadium, Mohali            Chandigarh        35
# Maharashtra Cricket Association Stadium               Pune              21
# Subrata Roy Sahara Stadium                            Pune              17
# Dr DY Patil Sports Academy                            Mumbai            17
# Kingsmead                                             Durban            15
# ...

# %%
#How many times did each team win the IPL championship?
winners = []
for season in sorted(list(df1['season'].unique())):
    every_season_last_match = df1[df1['season'] == season]
    winners.append(every_season_last_match.iloc[-1]['winner'])
print(pd.Series(winners).value_counts())
# Out:
# Mumbai Indians           4
# Chennai Super Kings      3
# Kolkata Knight Riders    2
# Rajasthan Royals         1
# Deccan Chargers          1
# Sunrisers Hyderabad      1
# dtype: int64

# %%
#How many matches were played in each season?
for season in sorted(list(df1['season'].unique())):
    every_season = df1[df1['season'] == season]
    print(f"Season :{season} , matches_played: {len(every_season)}")
# Out:
# Season :2008 , matches_played: 58
# Season :2009 , matches_played: 57
# Season :2010 , matches_played: 60
# Season :2011 , matches_played: 73
# Season :2012 , matches_played: 74
# Season :2013 , matches_played: 76
# Season :2014 , matches_played: 60
# Season :2015 , matches_played: 59
# Season :2016 , matches_played: 60
# Season :2017 , matches_played: 59
# Season :2018 , matches_played: 60
# Season :2019 , matches_played: 60

# %%
#How many matches were affected by the weather (DL applied or abandoned)?

df1['dl_applied'].value_counts()[1]
# Out:
# 19

# %%
#How many times did a team win both the toss and the match by choosing to bat?
df2 = df1[df1['toss_winner'] == df1['winner']]
len(df2[df2['win_by_runs'] > 0])
# Out:
# 135

# %%
#How many times did a team win both the toss and the match by choosing to field?
df2 = df1[df1['toss_winner'] == df1['winner']]
len(df2[df2['win_by_wickets'] > 0])
# Out:
# 253

# %%
# How many times did a team successfully chase a target?

len(df1[df1['win_by_wickets'] > 0])
# Out:
# 406

# %%
#How many matches were won by the team with the highest margin of victory?
margin = 100
len(df1[df1['win_by_runs'] > margin])
# Out:
# 9

# %%
#How many times did the team batting first win in a particular season?


all_seasons = sorted(list(df1['season'].unique()))
for season in all_seasons:
    season_data = df1[df1['season'] == season]
    winner = len(season_data[season_data['win_by_runs'] > 0])
    print(f"season : {season} and number of winner : {winner}")
# Out:
# season : 2008 and number of winner : 24
# season : 2009 and number of winner : 27
# season : 2010 and number of winner : 31
# season : 2011 and number of winner : 33
# season : 2012 and number of winner : 34
# season : 2013 and number of winner : 37
# season : 2014 and number of winner : 22
# season : 2015 and number of winner : 32
# season : 2016 and number of winner : 21
# season : 2017 and number of winner : 26
# season : 2018 and number of winner : 28
# season : 2019 and number of winner : 22

# %%
#How many times did the team batting second win in a particular season?


all_seasons = sorted(list(df1['season'].unique()))
for season in all_seasons:
    season_data = df1[df1['season'] == season]
    winner = len(season_data[season_data['win_by_wickets'] > 0])
    print(f"season : {season} and number of winner : {winner}")
# Out:
# season : 2008 and number of winner : 34
# season : 2009 and number of winner : 29
# season : 2010 and number of winner : 28
# season : 2011 and number of winner : 39
# season : 2012 and number of winner : 40
# season : 2013 and number of winner : 37
# season : 2014 and number of winner : 37
# season : 2015 and number of winner : 24
# season : 2016 and number of winner : 39
# season : 2017 and number of winner : 32
# season : 2018 and number of winner : 32
# season : 2019 and number of winner : 35
