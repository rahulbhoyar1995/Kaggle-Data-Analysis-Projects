# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/data-science-jobs-in-india/Data_Science_Jobs_in_India.csv

# %%
df = pd.read_csv("/kaggle/input/data-science-jobs-in-india/Data_Science_Jobs_in_India.csv")
df
# Out:
#       Unnamed: 0            company_name       job_title  min_experience  \
# 0              0                     TCS  Data Scientist               2
# 1              1               Accenture  Data Scientist               2
# 2              2                     IBM  Data Scientist               2
# 3              3               Cognizant  Data Scientist               2
# 4              4               Capgemini  Data Scientist               2
# ...          ...                     ...             ...             ...
# 1597        1597  Collabera Technologies  Data Architect               8
# 1598        1598                 Coforge  Data Architect               7
# 1599        1599                 Hitachi  Data Architect              21
# 1600        1600                GE Power  Data Architect               7
# 1601        1601               T-Systems  Data Architect              16
#
#      avg_salary min_salary max_salary  num_of_salaries
# ...

# %% [markdown]
# ### Experience vs. Salary:
#
# Is there a relationship between the minimum experience required and the average salary offered?
#
# How does the minimum experience required vary across different job titles?
#
# ### Salary Range Analysis:
#
# How does the salary range (min_salary to max_salary) vary across different companies?
#
# Are there any outliers in terms of salary offered by specific companies?
#
# ### Job Title Analysis:
#
# Which job titles are the most common in the dataset?
#
# Is there a difference in salary offered between different job titles?
#
# How does the distribution of job titles vary across companies?
#
# ### Company Analysis:
#
# Which companies offer the highest average salary for data science roles?
#
# How does the number of reported salaries vary across different companies?
#
# ### Salary Distribution:
#
# What is the distribution of salaries across different experience levels?
#
# How does the salary distribution vary across different job titles?
#
# ### Trend Analysis:
#
# Is there any trend in the average salary offered over the years (if your dataset includes a date)?
#
# Are there any seasonal trends in hiring or salary offered?
#
# ### Correlation Analysis:
#
# Is there any correlation between the number of reported salaries and the average salary offered?
#
# Is there any correlation between the minimum experience required and the average salary offered?
#
# ### Visualization:
#
# Create histograms or density plots to visualize the distribution of salaries, experience, and number of salaries.
#
# Use scatter plots to visualize the relationship between variables like experience and salary.
#
# ### Geographical Analysis (if applicable):
#
# Are there any regional differences in the average salary offered or the number of data science jobs?
# Which cities have the highest concentration of data science jobs?

# %% [markdown]
# ### (A) Descriptive Statistics:

# %% [markdown]
# What is the average, minimum, and maximum salary offered for data science jobs in India?

# %%
import pandas as pd

# Assuming your dataset is stored in a DataFrame named 'df'
# Filter the dataset for data science job titles
data_science_jobs = df[df['job_title'].isin(['Data Scientist', 'Senior Data Scientist', 'Machine Learning Engineer', 'Data Engineer', 'Data Analyst', 'Data Architect'])]

# Calculate the average, minimum, and maximum salary offered
average_salary = data_science_jobs['avg_salary'].mean()
min_salary = data_science_jobs['min_salary'].min()
max_salary = data_science_jobs['max_salary'].max()

print("Average Salary for Data Science Jobs in India:", average_salary)
print("Minimum Salary for Data Science Jobs in India:", min_salary)
print("Maximum Salary for Data Science Jobs in India:", max_salary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       5 data_science_jobs = df[df['job_title'].isin(['Data Scientist', 'Senior Data Scientist', 'Machine Learning Engineer', 'Data Engineer', 'Data Analyst', 'Data Architect'])]
#       7 # Calculate the average, minimum, and maximum salary offered
# ----> 8 average_salary = data_science_jobs['avg_salary'].mean()
#       9 min_salary = data_science_jobs['min_salary'].min()
#      10 max_salary = data_science_jobs['max_salary'].max()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# ...

# %% [markdown]
# What is the distribution of the number of salaries reported?

# %% [markdown]
# What is the distribution of job titles and companies in the dataset?
